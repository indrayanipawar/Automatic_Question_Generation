# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/task2/Question-Generator/
# !ls
# Out:
# /content/drive/MyDrive/task2/Question-Generator
#  after_spell_text.txt  'generatedQuestions (1).txt'   out_text.txt
#  Data		        generatedQuestions.txt	     'Question Generation'
#  Demo.ipynb	        Grammar
# 'Final Demo.ipynb'      ocr

# %%
# !pip install pickle5
import pickle5 as cPickle
from pathlib import Path

def dumpPickle(fileName, content):
    pickleFile = open(fileName, 'wb')
    cPickle.dump(content, pickleFile, -1)
    pickleFile.close()

def loadPickle(fileName):    
    file = open(fileName, 'rb')
    content = cPickle.load(file)
    file.close()
    
    return content
    
def pickleExists(fileName):
    file = Path(fileName)
    
    if file.is_file():
        return True
    
    return False
# Out:
# Collecting pickle5
#   Downloading https://files.pythonhosted.org/packages/f7/4c/5c4dd0462c8d3a6bc4af500a6af240763c2ebd1efdc736fc2c946d44b70a/pickle5-0.0.11.tar.gz (132kB)
#      |████████████████████████████████| 133kB 8.0MB/s
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py) ... done
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp37-cp37m-linux_x86_64.whl size=219261 sha256=64e243372597e58c6bb129c32824cce7cc3ae3ef40838703c782a08ca09efe27
#   Stored in directory: /root/.cache/pip/wheels/a6/90/95/f889ca4aa8b0e0c7f21c8470b6f5d6032f0390a3a141a9a3bd
# Successfully built pickle5
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.11

# %%
import gensim
from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors

glove_file = 'Data/glove.6B.300d.txt'
tmp_file = 'Data/word2vec-glove.6B.300d.txt'

from gensim.scripts.glove2word2vec import glove2word2vec
glove2word2vec(glove_file, tmp_file)
model = KeyedVectors.load_word2vec_format(tmp_file)

# %%
path = 'Data/distractor.pkl'
dumpPickle(path, model)

# %%
path = 'Data/distractor.pkl'
model = loadPickle(path)

# %%
distractions = model.most_similar(positive=['oxygen'], topn=10)
for i in range (len(distractions)):
    print (distractions[i], "\n")
# Out:
# ('hydrogen', 0.63267982006073)
#
# ('nitrogen', 0.6251459717750549)
#
# ('helium', 0.5435217022895813)
#
# ('nutrients', 0.5369840860366821)
#
# ('breathing', 0.5023170709609985)
#
# ('chlorine', 0.4946938157081604)
#
# ('monoxide', 0.4911428987979889)
#
# ('dioxide', 0.4911195933818817)
#
# ('ammonia', 0.49079084396362305)
#
# ('carbon', 0.4836854636669159)
