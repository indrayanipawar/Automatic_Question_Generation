# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/
# !ls
# Out:
# /content/drive/MyDrive
#  02-nov-batch-AssignmentData.gsheet
#  02-nov-final-Assignment-Data.gsheet
# '05-nov-2020-Subject-Wise Assignment data.gsheet'
#  05-nov-final-Addignment-data.gsheet
# '06.11.2020 Re Exam.gsheet'
# '06-nov-2020-subject wise assignmentData.gsheet'
#  06-nov-extra-assignment-verification.gsheet
#  06-nov-final-Results.xlsx
# '07.11.2020 Re Exam.gsheet'
#  07-nov-2020-final-Assignment-data.gsheet
#  07-nov-extra-tybas-ma-bcomcandidate-Assignment.gsheet
#  08-nov-2020-final-Assignment-verification.gsheet
#  08-nov-subjectwise-Assignment-data.gsheet
# '09.11.2020 Re Exam.gsheet'
# '09.11.2020 Re Exam.xlsx'
#  09-nov-2020-final-Assignment-Verification.gsheet
# '09-nov-2020-SubjectWise AssignmentData.gsheet'
#  12019015.pdf
#  1-Nov-final-Total-Assignments.gsheet
# '25November2020 - Final Assignment Data.gsheet'
# '26November2020 - Final Assignment Data.gsheet'
# '27November2020 - Batch Wise Assignment Data.gsheet'
# '27November2020 - Batch Wise Assignment Data.xlsx'
# '27November2020 - Final Assignment Data.gsheet'
#  28-0ct-final-Total-Assignments.gsheet
# '28November2020 - Final Assignment Data.gsheet'
# '28November2020 - Final Assignment Data - Remaining Candidates.gsheet'
#  2.pdf
#  7-nov-subjectwiseAssignmentData.gsheet
#  Absentpresentdata.gsheet
# 'additional data of mcom 2 03_11.gsheet'
# 'ADDITIONAL DATA OF MCOM 2  28_10.gsheet'
# 'additional_MCOM II Data Splashgain Format_2_students (1).gsheet'
# 'additional_MCOM II Data Splashgain Format_2_students.gsheet'
# 'AMOL MORE.pdf'
# 'Android Mobile app Tasks.gsheet'
#  app-debug.apk
#  AssignedCandidatesDec.xlsx
#  Associate-May18_Topicwise.xls
# 'BatchAssignmentDetails 02.11.2020 (1).gsheet'
# 'BatchAssignmentDetails 02.11.2020 (2).gsheet'
# 'BatchAssignmentDetails 02.11.2020.gsheet'
# 'BatchAssignmentDetails 06.11.2020 (1).gsheet'
# 'BatchAssignmentDetails 06.11.2020.gsheet'
# 'BatchAssignmentDetails 06.11.2020.xlsx'
# 'BatchAssignmentDetails 07.11.2020 (1).gsheet'
# 'BatchAssignmentDetails 07.11.2020 (2).gsheet'
# 'BatchAssignmentDetails 07.11.2020.gsheet'
# 'BatchAssignmentDetails 08.11.2020 (1).gsheet'
# 'BatchAssignmentDetails 08.11.2020.gsheet'
# 'BatchAssignmentDetails 09.11.2020 (1).gsheet'
# 'BatchAssignmentDetails 09.11.2020.gsheet'
# 'Batch Assignment Details 25.11.2020.gsheet'
#  BatchAssignmentDetailse.gsheet
# 'BatchAssignmentDetailse TY B Com Re-Test 06.11.gsheet'
# 'BatchAssignmentDetailse TY B Com Re-Test 06.11.xlsx'
# 'BatchAssignmentDetailse with student count (1).gsheet'
# 'BatchAssignmentDetailse with student count (1).xlsx'
# 'BatchAssignmentDetailse with student count.gsheet'
# 'BatchAssignmentDetailse with student count.xlsx'
#  BatchAssignmentDetailse.xlsx
# 'Batch Assignment Details Final  23.11.2020.gsheet'
# 'CandidateRecord(s).xls'
#  CDKeys.xls
#  CDKeys.xls.gsheet
# 'Center_Instructions_For Exam_25th Feb 2018.doc'
# 'Check Lists For Building Eklavvya 2.0.gsheet'
#  Chrome
#  CodingStandards.doc
#  CodingStandards.doc.gdoc
# 'Colab Notebooks'
# 'Computer Programming Assessment.gsheet'
#  com.splashgain.Eklavvya.Android-Signed.apk
# 'Copy of 07.11.2020 Re Exam.gsheet'
# 'Copy of 09.11.2020 Re Exam.gsheet'
# 'Copy of Issue File Mumbai University.xls'
# 'Current allocations (1).xlsx.gsheet'
# 'Current allocations.xlsx.gsheet'
#  DatabaseQuery.sql
# 'Demo Server Database.gsheet'
# 'Documentation of Copy Operating system (1).docx'
# 'Documentation of Copy Operating system.docx'
#  Ekalaavya_15_11_2017.zip
# 'eklavvya app bus.gsheet'
# 'eklavvya app bus.xlsx'
# 'Eklavvya Core 2.0 Release Details.gsheet'
#  Eklavvya_Core_DeadLine_Doccumets.gdoc
#  EklavvyaLive-UnUsedIndexStudy.gsheet
#  EklavvyamobileApp
# 'Eklavvya New Coulmns Addedd for Configurations.gsheet'
#  Eklavvya.Student.zip
#  ePravesh_Existing_Form_Code_Review.gsheet
#  Estimation_Template_WBS2.xlsx
# 'Faculty_detils_for_Proof_reading (02.11.2020).gsheet'
# 'Faculty_detils_for_Proof_reading (02.11.2020).xlsx'
# 'Faculty_detils_for_Proof_reading (03.11.2020).gsheet'
# 'Faculty_detils_for_Proof_reading (06.11.2020).gsheet'
# 'Faculty_detils_for_Proof_reading (07.11.2020).gsheet'
# 'Faculty_detils_for_Proof_reading (08.11.2020).gsheet'
# 'Faculty_detils_for_Proof_reading (09.11.2020).gsheet'
#  FeastApiRequirment.xlsx
#  FeastApiRequirment.xlsx.gsheet
#  FeastPublish.zip
# 'Final Result Batch-1.gsheet'
# 'Final Result Batch-2.gsheet'
#  GENERALMOTORSCORPAR2014.pdf
# 'Hbl Exam Result Data.gsheet'
# 'Hbl Exam Result Data.xlsx'
# 'Image Capturing (1).docx'
# 'Image Capturing.docx'
# 'incomplet student 2019-20  mcom 2.gsheet'
# 'incomplet student 2019-20  mcom 2.xls'
#  IndaslabTestYourSelf.zip
# 'Indrayani'\''s Resume (3)-1.gdoc'
# 'Indrayani'\''s Resume (3)-1.pdf'
#  InstitutewiserowCount.gsheet
#  kalptech.pdf
# 'Knowledge Is the Power Test It.gsite'
#  kubernetesdocks.gdoc
# 'linux server configurartion.gsheet'
#  List_Site_Troubleshooting_Server.gsheet
#  Lucidpress
# 'MA-MCom Absent Moc Data.gsheet'
# 'Manmark Subjective data.gsheet'
# 'Manmark subjetive assessment data.gsheet'
# 'MCOM II Data Splashgain Format.gsheet'
#  MockTestData_20_10_2020.gsheet
#  MockTestData_20_10_2020.xlsx
#  mu-MCOM-Result.gsheet
# 'MVC Session Feedback Form.gform'
#  Offline_Exam_Steps.gsheet
#  On_Screen_Road_Map
#  opt.zip
# 'Performance Evaluation Dev.docx'
#  Performance-Improvement-Plan-Ravina_Barkhade.docx
#  Performance-Improvement-Plan-Ravina_Barkhade.gdoc
# 'PHD Provisional.xlsx'
#  Pitch.gslides
#  PresentAndAbsentCount-Tyba-Tybcom-MA.gsheet
#  Presentation_Goals_Sept18.gslides
# 'Proctor Eklavvya.gsheet'
# 'Proctoring Client side code review.gsheet'
# 'Proctor Wise Candidate data.gsheet'
# 'Proctor Wise Candidate data.xls'
# 'Product_Roadmap_Estimation_SG (1).gsheet'
# 'Product_Roadmap_Estimation_SG (2).gsheet'
#  Product_Roadmap_Estimation_SG.gsheet
#  Product_Roadmap_Estimation_SG.xlsx
#  Product_RoadMap_SG
#  Programming.zip
# 'Ranchi questionimages'
# 'R & D Department goal Documentation.gdoc'
# 'R&D Roadmap.gsheet'
#  Report.gdoc
#  Report.pdf
#  Resourcing
# 'Road Map.gdoc'
#  scale.eklavvya.in-1567505798872.log
#  ServerLogins.gsheet
# 'Server_Logins Password.gsheet'
# 'session utilization.gsheet'
# 'session utilization.xlsx'
#  SG_backlog.gsheet
#  SG_backlog.xlsx
# 'Skill Android App Code Xamarine'
# 'Splashmlvm-2 Server upgrade and Downgrade Steps.gdoc'
# 'steps to configurevm.gdoc'
#  studentwiseExamCount.gsheet
# 'SUBJECT CHANGE OF MCOM PART 2_ 5_11.gsheet'
# 'Subjective evaluation report for first 30 candidates answers.xlsx'
# 'summary1 (1).gsheet'
#  summary1.csv
#  summary1.gsheet
#  summary3.gsheet
#  summary4.gsheet
# 'Summary Usage for Billing Period Jul 18, 2020 - Aug 18, 2020 (1).gsheet'
# 'Summary Usage for Billing Period Jul 18, 2020 - Aug 18, 2020 (2).gsheet'
# 'Summary Usage for Billing Period Jul 18, 2020 - Aug 18, 2020.gsheet'
# 'Summary Usage for Billing Period Jul 18, 2020 - Aug 18, 2020.xlsx'
#  Syngenta_New_Portal_Shifting.gdoc
#  task2
# 'Team Hrishi.gsheet'
#  Tes.gdoc
#  TrainingData
# 'TYBA EXAM QUARY 23-10 (1).gsheet'
# 'TYBA EXAM QUARY 23-10 (1).xlsx'
# 'TYBA EXAM QUARY 23-10 (2).gsheet'
# 'TYBA EXAM QUARY 23-10.gsheet'
# 'TYBA EXAM QUARY 23-10.xlsx'
# 'TyBA - for one student 7_11.gsheet'
#  tybcom-tyba-ma-result.gsheet
# 'Untitled document.gdoc'
# 'Untitled Jam.gjam'
# 'Untitled site.gsite'
# 'Untitled Site.gsite'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet (4).gsheet'
# 'Untitled spreadsheet (5).gsheet'
# 'Untitled spreadsheet (6).gsheet'
# 'Untitled spreadsheet (7).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'UPES April-May Proctored Exam Details.gsheet'
# 'UPES April-May Proctored Exam Details.xlsx'
# 'Vedio Decrypt.rar'
# 'Vss to vsts.gsheet'
# 'Web Api Code review.gsheet'
# 'WhatsApp Video 2020-10-01 at 5.45.18 PM.mp4'
# 'Workshop For Parents Teacher and Adults 2016 .xls'
#  हमीपत्र.docx

# %%
# %cd task2
# Out:
# /content/drive/.shortcut-targets-by-id/1d5vGWhfF32PmdcTSkxTbBk8uFtU1kYbF/task2

# %%
# !wget --no-check-certificate -P ./data/ "http://nlp.stanford.edu/data/glove.6B.zip"
# Out:
# --2021-04-17 07:50:24--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2021-04-17 07:50:24--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2021-04-17 07:50:24--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘./data/glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  5.06MB/s    in 2m 42s
#
# 2021-04-17 07:53:07 (5.07 MB/s) - ‘./data/glove.6B.zip’ saved [862182613/862182613]

# %%
# !ls data
# Out:
# glove.6B.zip

# %%
import zipfile 
local_zip = 'data/glove.6B.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('data')
zip_ref.close()
